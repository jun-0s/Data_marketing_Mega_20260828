# %% [markdown]
# 1. 왜 이 목표 및 미션이 필요한가?(마케팅적 시점) : 3C 분석 * 현재는 고민X
# 2. 목표 = 미션 : 네이버 포털사이트 내 뉴스 카테고리에서 특정 키워드 검색 시, 나오는 기사 제목을 수집해오기
# 3. 그동안 배웠던 문법 즉, 함수가 먼저 머리속에 나오면 X
#
# 5. 위 목표 및 미션을 해결하기 위한 절차 & 과정 = 프로세스 먼저 그려야함!!!
# 6. 네이버 포털사이트 > 뉴스 카테고리 : 문법?
# 7. 검색을 희망하는 키워드를 입력 : 첫번째 문법 어떻게 사용?
# 8. 키워드 입력 후 검색하기 버튼 클릭 : 문법?
# 9. 버튼 클릭 된 후 출력되고 있는 기사 제목 스캔
# 10. 기사 제목 스캔 후 상위 10개 기사 제목만 가져와야함

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in C:\Users\user\anaconda3\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\user\anaconda3\Lib\site-packages (from requests) (2026.6.17)

# %%
import requests
from bs4 import BeautifulSoup

query = input("검색하고싶은 키워드를 입력하세요")
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36"
} # 딕션어리

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.fender-ui_228e3bd1.ise_N8_wf_ooMaN2")
# soup -> select : 인자값과 동일한 값이기만 하면 몇개든지 찾아와!

for i, title in enumerate(titles[:10], 1) :
    print(f"{i}. {title.text}")
# Out:
# 검색하고싶은 키워드를 입력하세요 디지털마케팅
# 1. AI와 인간의 상상력이 만나면…부산국제마케팅광고제 개막새 창 열림
# 2. [기고] 마케팅은 이제 소프트웨어가 됐다새 창 열림
# 3. S-OIL, AI시대 디지털 혁신과 액침냉각유 사업 속도새 창 열림
# 4. “제주에서 배운다”… 한경닷컴·이랜드파크 ‘K-Tour LX 콘텐츠 마케팅...새 창 열림
# 5. 메디케이메이트, 중국 디지털 마케팅 연계 외국인환자 유치사업 확대새 창 열림
# 6. 용산 청년, 200만원 무역교육 무료로…AI 마케팅부터 취업까지 지원새 창 열림
# 7. 의사 마음 잡은 제약사 마케팅은 AI보다 '채널'···한미약품 7년째 1위새 창 열림
# 8. [人사이트] 이지혁 블럭스 대표 “자율집행 AI 에이전트로 CRM 마케팅 문...새 창 열림
# 9. [안산소식]'AI 활용 온라인 마케팅' 교육생 모집 등새 창 열림
# 10. LG생건, 미국 '에이본' 매각…디지털 중심으로 북미 사업 재편새 창 열림

# %%
import requests
from bs4 import BeautifulSoup

query = input("검색하고싶은 키워드를 입력하세요")
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/151.0.0.0 Safari/537.36"
} # 딕션어리

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

news_contents = soup.select("div.sds-comps-vertical-layout.sds-comps-full-layout.vlFp8ERAn58mSKma")

for i, content in enumerate(news_contents[:10], 1) :
    title = content.select_one("a.fender-ui_228e3bd1.ZdTBe0dB_G0DGXFC")
    body = content.select_one("a.fender-ui_228e3bd1.DPWFguOj6E7T6a6U")
    
# titles = content.select("a.fender-ui_228e3bd1.ZdTBe0dB_G0DGXFC")
# bodies = content.select("a.fender-ui_228e3bd1.DPWFguOj6E7T6a6U")

    title_text = title.text.strip()
    link = title.get("href")
    body_text = body.text.strip()

    print(f"{i}. {title_text} {link} {body_text}")

# for title in titles[:10] :
#     print(f"{i}. {title.text} {title.get("href")}")

# for body in bodies[:10] :
#     print(f"{i}. {body.text}")


# soup -> select : 인자값과 동일한 값이기만 하면 몇개든지 찾아와!
# Out:
# 검색하고싶은 키워드를 입력하세요 디지털마케팅
# 1. AI와 인간의 상상력이 만나면…부산국제마케팅광고제 개막새 창 열림 https://www.newsis.com/view/NISX20260826_0003762790 문화체육관광부는 부산광역시, 부산국제마케팅광고제조직위원회와 함께 26일부터 28일까지 시그니엘 부산과 해운대 일원에서 '2026... 최성희 문체부 콘텐츠산업정책관은 "AI 중심의 디지털 전환과 매체의 다변화 속에서 광고산업이 어떤 새로운 도약의 기회를 만들어갈지 기대가 크다. 문체부 역시 국내... 새 창 열림
# 2. 신한은행, 45기 대학생 홍보대사 발대식…AX 혁신·디지털 금융 아이디...새 창 열림 https://www.etnews.com/20260827000290 전국 37개 대학에서 선발된 80명은 올해 연말까지 신한은행 브랜드와 주요 사업을 경험하며 현장 마케팅과 콘텐츠 제작을 진행한다. 45기는 실무 연계형 참여 활동을 강화한다. 현업 부서와 함께 디지털 금융 서비스 개선 아이디어를 발굴하고, 인공지능 전환(AX) 혁신 고객 체감도를 분석한다. 청년층 일상... 새 창 열림
# 3. ‘챗GPT vs 제미나이’...돈 되는 한국 시장 놓고 마케팅 전쟁새 창 열림 https://www.chosun.com/economy/tech_it/2026/08/27/T62R7L2VHFCKNBRPYONNM27WYM/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news 두 회사는 또한 올여름 서울 도심에 있는 대형 디지털 전광판을 통해 앞다퉈 광고 영상도 내보냈다. IT 업계 관계자는 “두 회사의 마케팅을 보면 과거 국내 통신 3사의 가입자 유치 경쟁을 떠올리게 한다”면서 “유료 가입자를 얼마나 많이 확보하느냐가 수익성과 직결되는 만큼 생성형 AI 시장이... 새 창 열림
# 4. [기고] 마케팅은 이제 소프트웨어가 됐다새 창 열림 https://www.edaily.co.kr/News/Read?newsId=03188166645551256&mediaCodeNo=257&utm_source=naver&utm_medium=referral&utm_campaign=news_syndication&utm_content=original_article 검색엔진 최적화(SEO)와 AEO·GEO, 고객관계관리(CRM), 앱스토어 최적화(ASO), 퍼포먼스 마케팅(UA), 데이터 엔지니어링 등 디지털 마케팅 전 영역을 아우른다. NNT는 삼성전자, LG전자, 현대자동차, 배달의민족, 무신사 등 주요 기업과 350건 이상의 프로젝트를 수행하며 AI와 데이터를 실제 비즈니스 성장에... 새 창 열림
# 5. 트랜디랩, 맞춤형 디지털 마케팅 강화...브랜드·바이럴 전략 확대새 창 열림 http://www.beyondpost.co.kr/view.php?ud=2026082711263956249aeda69934_30 디지털 마케팅 전문기업 트랜디랩이 브랜드마케팅과 바이럴마케팅을 중심으로 기업별 맞춤형 마케팅 전략을 강화하고 서비스 영역 확대에 나선다. 디지털 마케팅 시장은 기술 발전과 소비 환경의 변화에 따라 빠르게 변화하고 있다. 소비자들이 단순한 광고 노출을 넘어 브랜드가 가진 가치와 스토리, 실제 경험... 새 창 열림
# 6. S-OIL, AI시대 디지털 혁신과 액침냉각유 사업 속도새 창 열림 https://www.mt.co.kr/industry/2026/08/26/2026082510270454454 전사적 디지털 전환 로드맵을 수립하고, 스마트 워크와 데이터 기반 의사결정, 디지털 공장·마케팅·인프라 등 5개 영역에 대한 DX(디지털 전환) 핵심과제를 지속 추진 중이다. S-OIL은 울산 온산공장을 세계 최고의 경쟁력을 갖춘 지능형 공장으로 혁신하기 위해 디지털 기술 기반의 S-imoms(통합 제조 운영... 새 창 열림
# 7. 롯데百, 외국인 결제부터 MD까지 ‘AI·디지털’ 전환 속도새 창 열림 https://www.viva100.com/article/20260827500182 롯데백화점이 외국인 고객의 쇼핑 편의를 높이는 결제 인프라를 확대하는 동시에 인공지능(AI)을 활용한 상품기획(MD) 역량 강화에 나서며 디지털 전환에... 박상우 롯데백화점 마케팅부문장은 “한국을 찾는 외국인 고객의 국적이 다변화되는 가운데 다양한 결제 수요에 대응하는 것은 글로벌 백화점으로... 새 창 열림
# 8. 메디케이메이트, 중국 디지털 마케팅 연계 외국인환자 유치사업 확대새 창 열림 https://www.mediafine.co.kr/news/articleView.html?idxno=88007 한수코퍼레이션은 그동안 중국 시장을 대상으로 디지털 마케팅과 콘텐츠를 운영하며 현지 온라인 플랫폼에 대한 경험을 축적해 왔다. 메디케이메이트는 이를 의료관광 분야와 연계해 온라인 홍보에서 실제 상담과 예약, 의료서비스 이용까지 이어지는 구조를 구축하는 데 초점을 맞췄다. 외국인환자 유치... 새 창 열림
# 9. 메디케이메이트, '마케팅·환자관리 결합'…중화권 의료관광 모델 추진새 창 열림 https://www.businessplus.kr/news/articleView.html?idxno=116021 한수코퍼레이션은 중국 시장을 대상으로 디지털 마케팅과 콘텐츠를 운영하면서 현지 온라인 플랫폼에 대한 경험을 축적해 왔다. 메디케이메이트는 이러한 경험과 중국인 고객 커뮤니케이션 역량을 의료관광 유치 실무에 결합해 온라인 홍보를 실제 상담과 예약, 의료서비스 이용으로 연결하는 데 중점을 두고... 새 창 열림
# 10. “제주에서 배운다”… 한경닷컴·이랜드파크 ‘K-Tour LX 콘텐츠 마케팅...새 창 열림 https://www.hankyung.com/article/202608262991O 한경닷컴 신명수 교육센터장은 “최근 관광 및 마케팅 산업에서 데이터 분석 역량과 생성형 AI 활용 능력을 갖춘 융합형 인재에 대한 수요가 급증하고 있다”며 “청년들이 제주의 자연과 현장을 직접 탐방하며 발굴한 소스가 차별화된 관광 웹진과 디지털 마케팅 성과로 연결될 수 있도록 실전 중심의... 새 창 열림

# %% [markdown]
# * 문제발생 : 직전 혹은 최근 작성했던 코드가 정상적으로 작동하지 않는다.
# * 왜 문제발생?
#
# - 클라이언트 & 서버 통신 정상적이지 못하다 (네이버 측에서 데이터 X)
# - soup = requests.get(url)
# - print(soup.text) : 클라이언트, 서버 통신 환경 = status
# - "200", 300, 400, 500
#
# - 서버에서는 데이터를 정상적으로 주고 있지만, 인터넷 환경이 좋지 못함 (우리 내부 인터넷 통신망 문제)
# - print(soup.text)
#
# - 네이버, 인터넷망이 이상없을 시 내부 코드상의 변화 (네이버 웹사이트 자체적인 코드 수정, 업데이트, 리뉴얼 등등)
# - a.fender-ui_228e3bd1.ZdTBe0dB_G0DGXFC
# - 코드가 바뀌는 것은 흔한 경우! 봇
