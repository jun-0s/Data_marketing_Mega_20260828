# %%
import re # regular expression -> 특정 문자열 안에서 원하는 문자 패턴만 가져오고 싶을 때
import requests # 특정 사이트 방문 -> 사이트 문서를 문자로 가져오기
from bs4 import BeautifulSoup # 문자타입으로 가져온 무서를 코드기반으로 읽어오기

url = "https://crawlingtest-260904-sejin.netlify.app/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("main#book-list > div.book")

book_list = list()

for book in books :
    
    # 책제목
    title_tag = book.select_one("h2.title")
    title = title_tag.get_text(strip=True)

    # 저자
    author_tag = book.select_one("p.author")
    author = author_tag.get_text(strip=True)

    # 출판사
    publisher_tag = book.select_one("p.publisher")
    publisher = publisher_tag.get_text(strip=True)

    # 판매가격
    price_tag = book.select_one("span.price")
    price_text = price_tag.get_text(strip=True)
    match = re.search(r"[\d,]+", price_text) # \d -> d : decimal(10진수)
    # 정규표현식 문법 : search -> 특정 문자 패턴에 해당되는 값을 찾으면 그 값을 가져온다
    price = int(match.group().replace(",", ""))

    # 평점
    rating_tag = book.select_one("span.rating")
    rating = float(rating_tag.get_text(strip=True))

    # 상세페이지 URL
    detail_tag = book.select_one("a.detail")
    detail_url = detail_tag.get("href")

    # 책 이미지 URL
    img_tag = book.select_one("img.book-img")
    img_url = img_tag.get("src")

    book_info = {
        "title": title,
        "author": author,
        "publisher": publisher,
        "price": price,
        "rating": rating,
        "detail_url": detail_url,
        "img_url": img_url
    }
    
    book_list.append(book_info)

print(book_list)
# Out:
# [{'title': '파이썬 데이터 분석 입문', 'author': '김작가', 'publisher': '데이터출판사', 'price': 25000, 'rating': 4.8, 'detail_url': 'book01.html', 'img_url': 'https://picsum.photos/seed/book1/200/250'}, {'title': 'Pandas 데이터 분석', 'author': '박작가', 'publisher': '분석출판사', 'price': 28000, 'rating': 4.7, 'detail_url': 'book02.html', 'img_url': 'https://picsum.photos/seed/book2/200/250'}, {'title': 'Python 웹 크롤링', 'author': '이작가', 'publisher': '웹북스', 'price': 30000, 'rating': 4.9, 'detail_url': 'book03.html', 'img_url': 'https://picsum.photos/seed/book3/200/250'}]

# %%
# Requests, BeautifulSoup 내용 -> Selenium 방식 데이터 수집 (왜?)
# 100% static = 정적인 사이트
# 사용자의 눈에 보이는 모든 요소들이 직접 html로 만들어졌다
# dynamic = 동적인 사이트
# 비록 사용자의 눈에는 보이지만, 그 요소들이 직접 html로 만들어지지 않고, JS라는
# 프로그래밍 언어를 통해서 만들어진 요소들로 구성되어있다.
# 기존 사이트에 데이터를 추가하는 방식 다양 => 1) html, 2) js, 3) api
# api = application programming interface

# 우리의 목표 ! = 개발자 X
# 데이터를 충분히 & 적극적 활용 (분석)마케터
# 데이터 수집 방법 : AI > 일환 (API)
