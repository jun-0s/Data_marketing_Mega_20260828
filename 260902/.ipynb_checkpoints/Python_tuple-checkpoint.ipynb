# %%
# parameter : 매개변수
# argument : 인수 = 인자값
def mul_return(a) :
    b = a + 1
    return a, b # 함수의 반환문, return은 반환 시, 값의 타입을 tuple로 반환

# %%
result = mul_return(1)
print(result, type(result))
# Out:
# (1, 2) <class 'tuple'>

# %%
len(result) # len = length 약어 = 길이 = tuple 자료구조 내 아이템 갯수
print(result[0]) # tuple, list => index를 가지고 있음
# Out:
# 1

# %%
# del result[3]

first, second = result # 구조분해할당 = unpacking

# %%
print(first, second)
# Out:
# 1 2

# %%
# tuple 자료구조 내부 assignment, deletion X
# tuple 자료구조 간 assignment 가능 (더하기, 배수외 불가능)

# %%
data1 = (1, 2, 3)
data2 = (4, 5, 6)

data3 = data1 +data2
print(data3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
data3 * 3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
data_list01 = [1, 2, 3] # 배열 = array
data_list01 = list()

data_tuple01 = (1, 2, 3)
data_tuple02 = tuple()

data_dict01 = dict[]
data_dict02 = {
    "한국": "kr",
    "일본": "jp",
}

# %%
type(data_dict01)
data_dict01["슬램덩크"] = "강백호" # 대괄호 표기법 => 값을 추가할 수 있음 = 값을 조회할수 있다

# %%
data_dict01
# Out:
# {'슬램덩크': '강백호', '피구와왕': '통키'}

# %%
data_dict01["피구왕"] = "통키"

# %%
data_dict01["슬램덩크"] # index값이 없음 / Key값으로만 찾을 수 있음
# Out:
# '강백호'

# %%
data_dict01["슬램덩크"] = "정대만" # dict는 값을 바꿀수 있음!

# %%
data_dict01
# Out:
# {}

# %%
del data_dict01["피구왕"] # 리스트에서 값을 제거하는 방법과 유사

# %%
del data_dict01["슬램덩크"]

# %%
data_dict01["리더"] = "GD"
data_dict01["보컬"] = "태양"
data_dict01["랩"] = "대성"

# %%
data_dict01
# Out:
# {'리더': 'GD', '보컬': '태양', '랩': '대성'}

# %%
# 하나의 셀에서 출력되는 값 : 기본적으로 맨마지막 문장만!!
# 만약 순서와 무관하게 출력 : print()

print(data_dict01.keys(), data_dict01.values(), data_dict01.items())
# Out:
# dict_keys(['리더', '보컬', '랩']) dict_values(['GD', '태양', '대성']) dict_items([('리더', 'GD'), ('보컬', '태양'), ('랩', '대성')])

# %%
key_items = data_dict01.keys()
print(type(key_items))
# 반복문 사용 : 리스트
# Out:
# <class 'dict_keys'>

# %%
for key in data_dict01.keys() :
    print(data_dict01[key])
# Out:
# GD
# 태양
# 대성

# %%
num01 = [1, 2, 3]
print(type(num01))

for num in num01 :
    print(num)
# Out:
# <class 'list'>
# 1
# 2
# 3

# %%
print(dir(num01), dir(key_items))
# 유사 리스트(list) = 리스트와 유사한 속성을 가지고 있음, 100% 동일한 리스트 X
# 반복문 사용 = 개체가 반복적인 속성인 것을 입증 => 반복문은 무조건 리스트만 가능 X
# 해당 개체 속성 안에 __iter__
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort'] ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__rsub__', '__rxor__', '__setattr__', 
# ...
