# %%
import requests
from bs4 import BeautifulSoup

url = ("https://www.jobkorea.co.kr/Search/?stext=%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%A7%88%EC%BC%80%ED%8C%85&tabType=recruit")

headers = {"User=agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
response.encoding="utf-8"
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("div.flex max-w-[643px] gap-2")

for title in titles[0:20] :
    # 타이틀
    title_tag = title.select_one("span.truncate text-gray900 text-typo-b4-14")
    title = title_tag.get_text(strip=True)
    
print(title)
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[7], line 12
#       8 response = requests.get(url, headers=headers)
#       9 response.encoding="utf-8"
#      10 soup = BeautifulSoup(response.text, "html.parser")
#      11
# ---> 12 titles = soup.select("div.flex max-w-[643px] gap-2")
#      13
#      14 for title in titles[0:20] :
#      15     # 타이틀
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:3333, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    3310 def select(
#    3311     self,
#    3312     selector: str,
#    (...)   3315     **kwargs: Any,
#    3316 ) -> ResultSet[Tag]:
#    3317     """Perform a CSS selection operation on the current element.
#    3318
#    3319     This uses the SoupSieve library.
#    (...)   3331        soupsieve.select() method.
#    3332     """
# ...
